# %% [markdown]
# Fatemeh Amanian

# %% [markdown]
# Train neural network models (at least two different networks for each dataset, i.e., no. layers, no. neurons, activations, ...) in either Tensorflow or Pytorch to perform regression on the following datasets:
#
# California Housing Values

# %%
import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot
import numpy as np
import pandas as pd
import sklearn
import math
import glob
import os
import sys
print("imported!")
# Out:
# imported!

# %%
path = "data"

# %% [markdown]
# Importing:

# %%
with open(path + '/housing.csv', newline='') as csvfile:
    housing = pd.read_csv(csvfile)

# %% [markdown]
# Let's view some of the data:

# %%
housing.shape
# Out:
# (20640, 10)

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# We have to prepare the data before doing any statistical analysis on it:

# %% [markdown]
# First let's search for the missing values.
# If the missing values are low, we can ignore them and remove them from the dataset.
# Else, if they are high, we can entirely ignore the column having so many NaNs.

# %%
print(housing.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# Not much, we can just remove them.

# %%
housing = housing.dropna(axis=0)
print(housing.isnull().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# Now we'll check for other anomalies in the data:

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20433 non-null float64
# latitude              20433 non-null float64
# housing_median_age    20433 non-null float64
# total_rooms           20433 non-null float64
# total_bedrooms        20433 non-null float64
# population            20433 non-null float64
# households            20433 non-null float64
# median_income         20433 non-null float64
# median_house_value    20433 non-null float64
# ocean_proximity       20433 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# Hmmm, it seems we have some non-numerical columns here. Let's check it out:

# %%
housing['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# Two thing to grasp here:
# First, it seems more like an interval value that have been classified into several groups.
# Second, we have only 5 records with the ocean_proximity attribute "ISLAND". So we might consider this as outliers and remove them.

# %%
# Convert type from object to category
housing.ocean_proximity = pd.Categorical(housing.ocean_proximity)
# Show the coding:
print(pd.Series(housing.ocean_proximity.cat.categories))
# Check out the codes to a new column:
housing['ocean_proximity_codes'] = housing.ocean_proximity.cat.codes
# Out:
# 0     <1H OCEAN
# 1        INLAND
# 2        ISLAND
# 3      NEAR BAY
# 4    NEAR OCEAN
# dtype: object

# %% [markdown]
# Remove the ISLAND outliers:

# %%
print(len(housing.index))
housing = housing.drop(housing[housing.ocean_proximity.values == 'ISLAND'].index)
print(len(housing.index))
# Out:
# 20433
# 20428

# %%
housing.ocean_proximity=housing.ocean_proximity.cat.remove_unused_categories()
print(pd.Series(housing.ocean_proximity.cat.categories))
# Out:
# 0     <1H OCEAN
# 1        INLAND
# 2      NEAR BAY
# 3    NEAR OCEAN
# dtype: object

# %% [markdown]
# Now let see some histograms:

# %%
housing.hist(bins=50,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D4F28CA708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48D96AC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48D9A6B08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D48D9DDBC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48DA14A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48DA4DB88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D48DA84C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48FC3CDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48FC489C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D48FC80B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48FCEB108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D48FD22088>]],
#       dtype=object)

# %% [markdown]
# Histograms where skewed too much to a side means the existance of some outliers on the opposite side.
#
# It also worth noting that there is a big lap in the end of the median_house_value and housing_median_age histograms which might be indicating that ancient houses, might worth a lot.

# %% [markdown]
# But we need more data to choose some **variables** as the **target** for our regressor to predict these variables for us.
#
# Let's start with some scatter plots:

# %% [markdown]
# First convert to fully numerical dataframe:

# %%
housing_numerical = housing.drop('ocean_proximity', axis=1)

# %%
c = pd.plotting.scatter_matrix(housing_numerical, alpha=0.2, figsize=(17, 17))
c;

# %% [markdown]
# We can see that there are good realtionships between some of the variables, for example household vs total_bedrooms.
# However, this feature is not a very useful one to predict. so we choose median_house_value. It has also an acceptable relationship with the median_income.

# %% [markdown]
# First we start splitting the data into variable-target sets:

# %%
# Split into variables and targets):
x = housing_numerical.copy().drop('median_house_value', axis=1)
y = housing_numerical.copy().pop('median_house_value')

# %% [markdown]
# Then, we split into validation and train sets:

# %%
from sklearn.model_selection import train_test_split
x_t, x_v, y_t, y_v = train_test_split(x, y, test_size=0.20, random_state=0)

# %% [markdown]
# We need to predict median_house_value from median_incomes:

# %% [markdown]
# Creating the model:

# %%
def build_model1():
    model = keras.Sequential([
        keras.layers.Dense(128, input_shape=[1,], activation="relu"),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dense(1)
    ])

    optimizer = tf.keras.optimizers.RMSprop(0.001, clipnorm=1)

    model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error',
                         'mean_squared_error'])
    return model

model1 = build_model1()
model1.summary()
# Out:
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               256
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 50,049
# Trainable params: 50,049
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training:

# %%
history = model1.fit(x_t['median_income'], y_t, validation_data=(x_v['median_income'], y_v), epochs=100)
# Out:
# WARNING:tensorflow:From c:\program files\python37\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:172: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 16342 samples, validate on 4086 samples
# Epoch 1/100
# 16342/16342 [==============================] - 1s 62us/sample - loss: 44043499050.6719 - mean_absolute_error: 176003.9375 - mean_squared_error: 44043530240.0000 - val_loss: 11145173739.3245 - val_mean_absolute_error: 74285.2266 - val_mean_squared_error: 11145177088.0000
# Epoch 2/100
# 16342/16342 [==============================] - 1s 58us/sample - loss: 7193432101.2831 - mean_absolute_error: 62608.6055 - mean_squared_error: 7193425408.0000 - val_loss: 6894565844.6442 - val_mean_absolute_error: 61351.8242 - val_mean_squared_error: 6894566400.0000
# Epoch 3/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7053010671.4889 - mean_absolute_error: 62556.4062 - mean_squared_error: 7053011456.0000 - val_loss: 6896613471.2325 - val_mean_absolute_error: 61980.3828 - val_mean_squared_error: 6896614400.0000
# Epoch 4/100
# 16342/16342 [==============================] - 1s 59us/sample - loss: 7051985076.1493 - mean_absolute_error: 62494.0625 - mean_squared_error: 7051986432.0000 - val_loss: 6895202087.8473 - val_mean_absolute_error: 62093.2852 - val_mean_squared_error: 6895202816.0000
# Epoch 5/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7052091408.1351 - mean_absolute_error: 62529.7031 - mean_squared_error: 7052090368.0000 - val_loss: 6895664256.8145 - val_mean_absolute_error: 61306.7852 - val_mean_squared_error: 6895664128.0000
# Epoch 6/100
# 16342/16342 [==============================] - 1s 57us/sample - loss: 7045467968.7598 - mean_absolute_error: 62523.6523 - mean_squared_error: 7045470208.0000 - val_loss: 6897629943.6045 - val_mean_absolute_error: 62237.1328 - val_mean_squared_error: 6897628672.0000
# Epoch 7/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7048035033.3697 - mean_absolute_error: 62557.7266 - mean_squared_error: 7048032768.0000 - val_loss: 6907357081.3744 - val_mean_absolute_error: 62513.3008 - val_mean_squared_error: 6907358208.0000
# Epoch 8/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7043979987.0097 - mean_absolute_error: 62419.7500 - mean_squared_error: 7043977216.0000 - val_loss: 6887306032.9946 - val_mean_absolute_error: 61784.3438 - val_mean_squared_error: 6887307264.0000
# Epoch 9/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7046546539.0244 - mean_absolute_error: 62454.1445 - mean_squared_error: 7046543360.0000 - val_loss: 6899263507.5477 - val_mean_absolute_error: 62344.1367 - val_mean_squared_error: 6899262464.0000
# Epoch 10/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7049296556.6614 - mean_absolute_error: 62354.5000 - mean_squared_error: 7049294336.0000 - val_loss: 6889440397.8463 - val_mean_absolute_error: 61996.8633 - val_mean_squared_error: 6889440256.0000
# Epoch 11/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7046573235.6480 - mean_absolute_error: 62479.9570 - mean_squared_error: 7046575104.0000 - val_loss: 6888456827.0504 - val_mean_absolute_error: 61805.8047 - val_mean_squared_error: 6888456704.0000
# Epoch 12/100
# 16342/16342 [==============================] - 1s 51us/sample - loss: 7049890308.5116 - mean_absolute_error: 62653.5391 - mean_squared_error: 7049884160.0000 - val_loss: 6912790204.2095 - val_mean_absolute_error: 62553.0898 - val_mean_squared_error: 6912791552.0000
# Epoch 13/100
# 16342/16342 [==============================] - 1s 51us/sample - loss: 7045294787.2505 - mean_absolute_error: 62439.3203 - mean_squared_error: 7045297152.0000 - val_loss: 6889344818.2477 - val_mean_absolute_error: 61537.3086 - val_mean_squared_error: 6889345536.0000
# Epoch 14/100
# 16342/16342 [==============================] - 1s 52us/sample - loss: 7053507933.4583 - mean_absolute_error: 62614.9219 - mean_squared_error: 7053500416.0000 - val_loss: 6888602285.9246 - val_mean_absolute_error: 61677.6836 - val_mean_squared_error: 6888602112.0000
# Epoch 15/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7045278883.2936 - mean_absolute_error: 62537.6172 - mean_squared_error: 7045279232.0000 - val_loss: 6891820547.7592 - val_mean_absolute_error: 61415.6211 - val_mean_squared_error: 6891820544.0000
# Epoch 16/100
# 16342/16342 [==============================] - 1s 60us/sample - loss: 7049944809.5362 - mean_absolute_error: 62522.7266 - mean_squared_error: 7049942528.0000 - val_loss: 6894362918.7195 - val_mean_absolute_error: 61345.9609 - val_mean_squared_error: 6894364672.0000
# Epoch 17/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7050449740.7906 - mean_absolute_error: 62499.5352 - mean_squared_error: 7050451456.0000 - val_loss: 6925267769.0142 - val_mean_absolute_error: 60931.2500 - val_mean_squared_error: 6925265408.0000
# Epoch 18/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7048549265.4040 - mean_absolute_error: 62457.6445 - mean_squared_error: 7048548352.0000 - val_loss: 6892863717.0592 - val_mean_absolute_error: 61385.5078 - val_mean_squared_error: 6892865536.0000
# Epoch 19/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7052327798.3973 - mean_absolute_error: 62499.0625 - mean_squared_error: 7052324352.0000 - val_loss: 6920553967.5849 - val_mean_absolute_error: 62804.0586 - val_mean_squared_error: 6920553984.0000
# Epoch 20/100
# 16342/16342 [==============================] - 1s 52us/sample - loss: 7046634139.0851 - mean_absolute_error: 62472.5508 - mean_squared_error: 7046635008.0000 - val_loss: 6896707662.9427 - val_mean_absolute_error: 61327.2969 - val_mean_squared_error: 6896706048.0000
# Epoch 21/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7045280670.3747 - mean_absolute_error: 62617.8164 - mean_squared_error: 7045281792.0000 - val_loss: 6886909902.8801 - val_mean_absolute_error: 61937.9727 - val_mean_squared_error: 6886909952.0000
# Epoch 22/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7040774481.9914 - mean_absolute_error: 62536.6094 - mean_squared_error: 7040773120.0000 - val_loss: 6941004242.1380 - val_mean_absolute_error: 63192.4531 - val_mean_squared_error: 6941005312.0000
# Epoch 23/100
# 16342/16342 [==============================] - 1s 56us/sample - loss: 7052151908.3197 - mean_absolute_error: 62561.9141 - mean_squared_error: 7052148736.0000 - val_loss: 6887063534.4572 - val_mean_absolute_error: 62025.9961 - val_mean_squared_error: 6887062528.0000
# Epoch 24/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7045188691.3386 - mean_absolute_error: 62429.7734 - mean_squared_error: 7045191680.0000 - val_loss: 6886347610.5962 - val_mean_absolute_error: 61916.7852 - val_mean_squared_error: 6886348288.0000
# Epoch 25/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7044439897.6674 - mean_absolute_error: 62605.8203 - mean_squared_error: 7044440064.0000 - val_loss: 6887484693.1767 - val_mean_absolute_error: 61931.1133 - val_mean_squared_error: 6887484416.0000
# Epoch 26/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7046575084.3872 - mean_absolute_error: 62610.1406 - mean_squared_error: 7046571008.0000 - val_loss: 6900799484.8674 - val_mean_absolute_error: 62466.1367 - val_mean_squared_error: 6900800000.0000
# Epoch 27/100
# 16342/16342 [==============================] - 1s 56us/sample - loss: 7044194133.3751 - mean_absolute_error: 62630.5586 - mean_squared_error: 7044192768.0000 - val_loss: 6891505707.8571 - val_mean_absolute_error: 62245.3672 - val_mean_squared_error: 6891505664.0000
# Epoch 28/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7041285252.8405 - mean_absolute_error: 62548.2539 - mean_squared_error: 7041278976.0000 - val_loss: 6885959311.3500 - val_mean_absolute_error: 61705.6523 - val_mean_squared_error: 6885960192.0000
# Epoch 29/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7041873937.7956 - mean_absolute_error: 62644.7383 - mean_squared_error: 7041873920.0000 - val_loss: 6885414667.4028 - val_mean_absolute_error: 61745.0430 - val_mean_squared_error: 6885414400.0000
# Epoch 30/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7040260177.5528 - mean_absolute_error: 62600.9453 - mean_squared_error: 7040263168.0000 - val_loss: 6893028301.8776 - val_mean_absolute_error: 62324.7656 - val_mean_squared_error: 6893028864.0000
# Epoch 31/100
# 16342/16342 [==============================] - 1s 56us/sample - loss: 7049667463.6916 - mean_absolute_error: 62525.3672 - mean_squared_error: 7049669120.0000 - val_loss: 6889748359.9569 - val_mean_absolute_error: 62093.1953 - val_mean_squared_error: 6889749504.0000
# Epoch 32/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7046565789.1215 - mean_absolute_error: 62651.3516 - mean_squared_error: 7046563840.0000 - val_loss: 6887439899.8179 - val_mean_absolute_error: 61935.8164 - val_mean_squared_error: 6887439872.0000
# Epoch 33/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7047085772.8376 - mean_absolute_error: 62677.3828 - mean_squared_error: 7047088128.0000 - val_loss: 6901808739.2423 - val_mean_absolute_error: 61221.8008 - val_mean_squared_error: 6901812224.0000
# Epoch 34/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7044968280.9468 - mean_absolute_error: 62496.8359 - mean_squared_error: 7044967936.0000 - val_loss: 6902476952.8732 - val_mean_absolute_error: 62557.7734 - val_mean_squared_error: 6902479872.0000
# Epoch 35/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7051634105.3188 - mean_absolute_error: 62713.5547 - mean_squared_error: 7051636224.0000 - val_loss: 6887605718.3984 - val_mean_absolute_error: 61586.8516 - val_mean_squared_error: 6887606784.0000
# Epoch 36/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7048465432.9389 - mean_absolute_error: 62580.8984 - mean_squared_error: 7048466944.0000 - val_loss: 6887446445.2981 - val_mean_absolute_error: 62074.0547 - val_mean_squared_error: 6887448576.0000
# Epoch 37/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7046943928.4729 - mean_absolute_error: 62572.5586 - mean_squared_error: 7046943232.0000 - val_loss: 6885554288.7753 - val_mean_absolute_error: 61925.4531 - val_mean_squared_error: 6885555712.0000
# Epoch 38/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7045399160.0578 - mean_absolute_error: 62638.4219 - mean_squared_error: 7045397504.0000 - val_loss: 6888247769.4058 - val_mean_absolute_error: 61571.3594 - val_mean_squared_error: 6888247296.0000
# Epoch 39/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7041370986.8677 - mean_absolute_error: 62709.0234 - mean_squared_error: 7041376256.0000 - val_loss: 6887151636.0489 - val_mean_absolute_error: 62095.5938 - val_mean_squared_error: 6887151616.0000
# Epoch 40/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7042268053.3516 - mean_absolute_error: 62536.8711 - mean_squared_error: 7042270208.0000 - val_loss: 6884932407.0093 - val_mean_absolute_error: 61809.0469 - val_mean_squared_error: 6884932608.0000
# Epoch 41/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7044688845.1196 - mean_absolute_error: 62617.9336 - mean_squared_error: 7044687872.0000 - val_loss: 6889561906.4983 - val_mean_absolute_error: 62230.5391 - val_mean_squared_error: 6889560064.0000
# Epoch 42/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7042646248.4709 - mean_absolute_error: 62742.7930 - mean_squared_error: 7042645504.0000 - val_loss: 6908767842.4905 - val_mean_absolute_error: 62702.8555 - val_mean_squared_error: 6908768768.0000
# Epoch 43/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7046270053.8549 - mean_absolute_error: 62756.2031 - mean_squared_error: 7046265856.0000 - val_loss: 6890973849.8757 - val_mean_absolute_error: 62142.1641 - val_mean_squared_error: 6890973696.0000
# Epoch 44/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7044709803.2202 - mean_absolute_error: 62562.8711 - mean_squared_error: 7044713984.0000 - val_loss: 6893668618.1498 - val_mean_absolute_error: 62233.6367 - val_mean_squared_error: 6893670400.0000
# Epoch 45/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7049078803.4248 - mean_absolute_error: 62554.6016 - mean_squared_error: 7049078272.0000 - val_loss: 6930365123.2266 - val_mean_absolute_error: 60982.1680 - val_mean_squared_error: 6930365952.0000
# Epoch 46/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7048490611.9848 - mean_absolute_error: 62617.6602 - mean_squared_error: 7048491520.0000 - val_loss: 6920775011.3676 - val_mean_absolute_error: 61046.6484 - val_mean_squared_error: 6920775680.0000
# Epoch 47/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7050346644.7563 - mean_absolute_error: 62469.9688 - mean_squared_error: 7050345984.0000 - val_loss: 6900080033.0181 - val_mean_absolute_error: 62432.9062 - val_mean_squared_error: 6900079104.0000
# Epoch 48/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7043023020.3794 - mean_absolute_error: 62615.2930 - mean_squared_error: 7043022336.0000 - val_loss: 6891626493.2433 - val_mean_absolute_error: 61427.2227 - val_mean_squared_error: 6891625472.0000
# Epoch 49/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7041737559.6309 - mean_absolute_error: 62505.4141 - mean_squared_error: 7041739264.0000 - val_loss: 6909693503.6554 - val_mean_absolute_error: 62595.5000 - val_mean_squared_error: 6909691392.0000
# Epoch 50/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7047869743.5281 - mean_absolute_error: 62529.9258 - mean_squared_error: 7047868928.0000 - val_loss: 6888922277.9050 - val_mean_absolute_error: 61676.8008 - val_mean_squared_error: 6888920576.0000
# Epoch 51/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7052357747.6715 - mean_absolute_error: 62445.7891 - mean_squared_error: 7052355584.0000 - val_loss: 6889671049.7112 - val_mean_absolute_error: 61823.9062 - val_mean_squared_error: 6889670144.0000
# Epoch 52/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7045166633.4187 - mean_absolute_error: 62483.5078 - mean_squared_error: 7045170176.0000 - val_loss: 6888725591.5888 - val_mean_absolute_error: 61981.2539 - val_mean_squared_error: 6888723968.0000
# Epoch 53/100
# 16342/16342 [==============================] - 1s 56us/sample - loss: 7045049868.0935 - mean_absolute_error: 62546.8008 - mean_squared_error: 7045047296.0000 - val_loss: 6888414517.0044 - val_mean_absolute_error: 62070.1328 - val_mean_squared_error: 6888414208.0000
# Epoch 54/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 
100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7045712947.7577 - mean_absolute_error: 62752.3438 - mean_squared_error: 7045710336.0000 - val_loss: 6886810172.1468 - val_mean_absolute_error: 62098.1680 - val_mean_squared_error: 6886807552.0000
# Epoch 97/100
# 16342/16342 [==============================] - 1s 53us/sample - loss: 7043529732.7622 - mean_absolute_error: 62545.8008 - mean_squared_error: 7043527680.0000 - val_loss: 6937270139.1757 - val_mean_absolute_error: 63292.5664 - val_mean_squared_error: 6937268224.0000
# Epoch 98/100
# 16342/16342 [==============================] - 1s 56us/sample - loss: 7048261924.7505 - mean_absolute_error: 62579.2734 - mean_squared_error: 7048260096.0000 - val_loss: 6886982430.9506 - val_mean_absolute_error: 61687.5312 - val_mean_squared_error: 6886983680.0000
# Epoch 99/100
# 16342/16342 [==============================] - 1s 54us/sample - loss: 7042579694.2357 - mean_absolute_error: 62619.5898 - mean_squared_error: 7042580480.0000 - val_loss: 6885153955.9001 - val_mean_absolute_error: 61797.5977 - val_mean_squared_error: 6885154304.0000
# Epoch 100/100
# 16342/16342 [==============================] - 1s 55us/sample - loss: 7047573596.4871 - mean_absolute_error: 62543.6875 - mean_squared_error: 7047577088.0000 - val_loss: 6884630416.4777 - val_mean_absolute_error: 61901.9883 - val_mean_squared_error: 6884628480.0000

# %% [markdown]
# Evaluations:

# %%
val = model1.evaluate(x_v['median_income'], y_v, verbose=2)

print("Testing: Loss: {:.5f}, Mean Absolute Error: {:.5f}, MSE: {:.5f} for median_house_value".format(val[0],val[1],val[2]))
# Out:
# 4086/4086 - 0s - loss: 6884630412.4679 - mean_absolute_error: 61901.9844 - mean_squared_error: 6884629504.0000
# Testing: Loss: 6884630412.46794, Mean Absolute Error: 61901.98438, MSE: 6884629504.00000 for median_house_value

# %% [markdown]
# Visualization:
#
# Visualizing the Loss and Accuracy vs epochs:

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    pyplot.figure(figsize=(15,5))

    pyplot.subplot(121)
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Mean Abs Error')
    pyplot.plot(hist['epoch'], hist['mean_absolute_error'], label='Train Error')
    pyplot.plot(hist['epoch'], hist['val_mean_absolute_error'], label = 'Validation Error')
    pyplot.legend()

    pyplot.subplot(122)
    pyplot.xlabel('Epoch')
    pyplot.ylabel('Mean Square Error')
    pyplot.plot(hist['epoch'], hist['mean_squared_error'], label='Train Error')
    pyplot.plot(hist['epoch'], hist['val_mean_squared_error'], label = 'Validation Error')
    pyplot.legend()
    pyplot.show()


plot_history(history)

# %% [markdown]
# Predictions:

# %%
test_predictions = model1.predict(x_v['median_income']).flatten()

predicted_loss = np.abs(y_v.values[0:4]-test_predictions[0:4])/y_v.describe().transpose()['mean']

# print("Median Income:\n", x['median_income'].values[0:4])
print("\nReal Median House Value:\n", y_v.values[0:4])
print("\nPredicted Median House Value:\n", test_predictions[0:4])
print("\nLoss:\n", predicted_loss)
# Out:
# Real Median House Value:
#  [182600. 201100.  74200. 245000.]
#
# Predicted Median House Value:
#  [166448.55 213933.53 148221.64 238641.22]
#
# Loss:
#  [0.07803433 0.06200408 0.35762905 0.03072189]

# %%
def plot_results(X, Y, Y_predict, plot_name):
    pyplot.figure()
    pyplot.scatter(Y, Y_predict)
    pyplot.grid()
    pyplot.xlabel("Real Values")
    pyplot.ylabel("Predictions")
    pyplot.figure()
    pyplot.scatter(X, Y, label="values")
    pyplot.plot(X, Y_predict, color="red", label="model")
    pyplot.grid()
    pyplot.xlabel("median_income")
    pyplot.ylabel("median_house_value")
    pyplot.legend()

test_predictions = model1.predict(x_v['median_income']).flatten()
plot_results(x_v['median_income'], y_v, test_predictions, "results_nn.png")

# %% [markdown]
# Hmmm, not a good linear line, but almost makes it.

# %%
error = test_predictions - y_v
pyplot.hist(error, bins = 25)
pyplot.xlabel("Prediction Error")
_ = pyplot.ylabel("Count")
pyplot.show()

# %% [markdown]
# Let's do it agian using another model, and this time we add more layers.

# %%
def build_model2():
    model = keras.Sequential()
    model.add(keras.layers.Dense(128, input_shape=[1,], activation="relu"))
    for i in range(3):
        model.add(keras.layers.Dropout(.2))
        model.add(keras.layers.Dense(256, activation="relu"))
    model.add(keras.layers.Dense(128, activation="relu"))
    model.add(keras.layers.Dense(1))
    
    optimizer = tf.keras.optimizers.RMSprop(0.001, clipnorm=1)

    model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error',
                         'mean_squared_error',
                         'mean_squared_logarithmic_error'])
    return model

model2 = build_model2()
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 128)               256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 197,889
# Trainable params: 197,889
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(
    x_t['median_income'], y_t,
    validation_data=(x_v['median_income'], y_v),
    verbose=1, epochs=100)
# Out:
# Train on 16342 samples, validate on 4086 samples
# Epoch 1/100
# 16342/16342 [==============================] - 3s 178us/sample - loss: 12274874244.9972 - mean_absolute_error: 78742.4141 - mean_squared_error: 12274865152.0000 - mean_squared_logarithmic_error: 3.1368 - val_loss: 6902131291.8492 - val_mean_absolute_error: 61642.6094 - val_mean_squared_error: 6902130688.0000 - val_mean_squared_logarithmic_error: 0.1798
# Epoch 2/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7457910451.9613 - mean_absolute_error: 64142.9414 - mean_squared_error: 7457909248.0000 - mean_squared_logarithmic_error: 0.1883 - val_loss: 7136613570.0989 - val_mean_absolute_error: 65516.7305 - val_mean_squared_error: 7136613888.0000 - val_mean_squared_logarithmic_error: 0.1974
# Epoch 3/100
# 16342/16342 [==============================] - 2s 133us/sample - loss: 7493091814.9984 - mean_absolute_error: 64591.4141 - mean_squared_error: 7493092864.0000 - mean_squared_logarithmic_error: 0.1896 - val_loss: 6908700510.1047 - val_mean_absolute_error: 61209.7070 - val_mean_squared_error: 6908699136.0000 - val_mean_squared_logarithmic_error: 0.1780
100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7469389706.1980 - mean_absolute_error: 64307.3828 - mean_squared_error: 7469392384.0000 - mean_squared_logarithmic_error: 0.1877 - val_loss: 6914556068.9026 - val_mean_absolute_error: 62865.0039 - val_mean_squared_error: 6914555392.0000 - val_mean_squared_logarithmic_error: 0.1861
# Epoch 23/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7407832310.8829 - mean_absolute_error: 64313.3633 - mean_squared_error: 7407829504.0000 - mean_squared_logarithmic_error: 0.1880 - val_loss: 7572811524.3857 - val_mean_absolute_error: 69101.1094 - val_mean_squared_error: 7572810752.0000 - val_mean_squared_logarithmic_error: 0.2120
# Epoch 24/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7436591267.9829 - mean_absolute_error: 64126.6914 - mean_squared_error: 7436589056.0000 - mean_squared_logarithmic_error: 0.1877 - val_loss: 7216559850.5727 - val_mean_absolute_error: 60688.5391 - val_mean_squared_error: 7216557056.0000 - val_mean_squared_logarithmic_error: 0.1737
# Epoch 25/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7507093360.5698 - mean_absolute_error: 64434.7891 - mean_squared_error: 7507095040.0000 - mean_squared_logarithmic_error: 0.1891 - val_loss: 6977529357.0318 - val_mean_absolute_error: 60859.9297 - val_mean_squared_error: 6977529856.0000 - val_mean_squared_logarithmic_error: 0.1757
# Epoch 26/100
# 16342/16342 [==============================] - 2s 137us/sample - loss: 7397512624.1390 - mean_absolute_error: 64197.5820 - mean_squared_error: 7397513728.0000 - mean_squared_logarithmic_error: 0.1884 - val_loss: 7017510942.1987 - val_mean_absolute_error: 60731.5469 - val_mean_squared_error: 7017512448.0000 - val_mean_squared_logarithmic_error: 0.1748
# Epoch 27/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7444608211.3543 - mean_absolute_error: 64226.2695 - mean_squared_error: 7444608000.0000 - mean_squared_logarithmic_error: 0.1877 - val_loss: 7189400039.6907 - val_mean_absolute_error: 60786.8711 - val_mean_squared_error: 7189402624.0000 - val_mean_squared_logarithmic_error: 0.1739
# Epoch 28/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7410696932.7740 - mean_absolute_error: 64164.9609 - mean_squared_error: 7410702848.0000 - mean_squared_logarithmic_error: 0.1874 - val_loss: 7073547291.8179 - val_mean_absolute_error: 60755.3945 - val_mean_squared_error: 7073546752.0000 - val_mean_squared_logarithmic_error: 0.1745
# Epoch 29/100
# 16342/16342 [==============================] - 2s 135us/sample - loss: 7429524238.5059 - mean_absolute_error: 64308.0391 - mean_squared_error: 7429523968.0000 - mean_squared_logarithmic_error: 0.1875 - val_loss: 6900541127.9883 - val_mean_absolute_error: 62418.6094 - val_mean_squared_error: 6900542464.0000 - val_mean_squared_logarithmic_error: 0.1838
# Epoch 30/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7445897538.5456 - mean_absolute_error: 64455.7617 - mean_squared_error: 7445895680.0000 - mean_squared_logarithmic_error: 0.1886 - val_loss: 6885257304.7166 - val_mean_absolute_error: 61877.1523 - val_mean_squared_error: 6885258240.0000 - val_mean_squared_logarithmic_error: 0.1813
# Epoch 31/100
# 16342/16342 [==============================] - 2s 137us/sample - loss: 7417230501.1734 - mean_absolute_error: 64209.8242 - mean_squared_error: 7417230848.0000 - mean_squared_logarithmic_error: 0.1882 - val_loss: 7131787365.2472 - val_mean_absolute_error: 65350.0625 - val_mean_squared_error: 7131787776.0000 - val_mean_squared_logarithmic_error: 0.1960
# Epoch 32/100
# 16342/16342 [==============================] - 2s 136us/sample - loss: 7408651490.9568 - mean_absolute_error: 64194.8438 - mean_squared_error: 7408651264.0000 - mean_squared_logarithmic_error: 0.1876 - val_loss: 6939040197.7327 - val_mean_absolute_error: 61051.7930 - val_mean_squared_error: 6939040768.0000 - val_mean_squared_logarithmic_error: 0.1768
# Epoch 33/100
# 16342/16342 [==============================] - 2s 139us/sample - loss: 7399005510.2112 - mean_absolute_error: 64078.3906 - mean_squared_error: 7399008256.0000 - mean_squared_logarithmic_error: 0.1877 - val_loss: 6964304408.3093 - val_mean_absolute_error: 63699.7695 - val_mean_squared_error: 6964301824.0000 - val_mean_squared_logarithmic_error: 0.1898
# Epoch 34/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7366553986.9764 - mean_absolute_error: 64041.3516 - mean_squared_error: 7366554112.0000 - mean_squared_logarithmic_error: 0.1875 - val_loss: 7077822944.1723 - val_mean_absolute_error: 60709.1172 - val_mean_squared_error: 7077823488.0000 - val_mean_squared_logarithmic_error: 0.1740
# Epoch 35/100
# 16342/16342 [==============================] - 2s 137us/sample - loss: 7430655633.3727 - mean_absolute_error: 64238.8594 - mean_squared_error: 7430656512.0000 - mean_squared_logarithmic_error: 0.1878 - val_loss: 6901007475.0308 - val_mean_absolute_error: 62641.6406 - val_mean_squared_error: 6901007360.0000 - val_mean_squared_logarithmic_error: 0.1846
# Epoch 36/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7374851647.0993 - mean_absolute_error: 63986.3945 - mean_squared_error: 7374851584.0000 - mean_squared_logarithmic_error: 0.1864 - val_loss: 6879959976.5365 - val_mean_absolute_error: 62103.1172 - val_mean_squared_error: 6879959040.0000 - val_mean_squared_logarithmic_error: 0.1820
# Epoch 37/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7372347721.6576 - mean_absolute_error: 64019.0742 - mean_squared_error: 7372347904.0000 - mean_squared_logarithmic_error: 0.1864 - val_loss: 6923687758.0656 - val_mean_absolute_error: 63152.8242 - val_mean_squared_error: 6923686912.0000 - val_mean_squared_logarithmic_error: 0.1868
# Epoch 38/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7372243695.1756 - mean_absolute_error: 64015.2031 - mean_squared_error: 7372247552.0000 - mean_squared_logarithmic_error: 0.1856 - val_loss: 7072551903.1698 - val_mean_absolute_error: 60784.8867 - val_mean_squared_error: 7072552448.0000 - val_mean_squared_logarithmic_error: 0.1737
# Epoch 39/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7382986091.0557 - mean_absolute_error: 64055.3359 - mean_squared_error: 7382985728.0000 - mean_squared_logarithmic_error: 0.1865 - val_loss: 6885702842.2046 - val_mean_absolute_error: 61073.7227 - val_mean_squared_error: 6885702144.0000 - val_mean_squared_logarithmic_error: 0.1762
# Epoch 40/100
# 16342/16342 [==============================] - 2s 137us/sample - loss: 7366702833.0554 - mean_absolute_error: 63767.4219 - mean_squared_error: 7366702080.0000 - mean_squared_logarithmic_error: 0.1851 - val_loss: 7573679922.4983 - val_mean_absolute_error: 61446.2109 - val_mean_squared_error: 7573678592.0000 - val_mean_squared_logarithmic_error: 0.1740
# Epoch 41/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7410133283.7479 - mean_absolute_error: 64073.7031 - mean_squared_error: 7410133504.0000 - mean_squared_logarithmic_error: 0.1853 - val_loss: 7210295179.4655 - val_mean_absolute_error: 66330.5312 - val_mean_squared_error: 7210295296.0000 - val_mean_squared_logarithmic_error: 0.1997
# Epoch 42/100
# 16342/16342 [==============================] - 2s 137us/sample - loss: 
# Epoch 90/100
# 16342/16342 [==============================] - 2s 143us/sample - loss: 7224597301.6688 - mean_absolute_error: 63323.3164 - mean_squared_error: 7224599040.0000 - mean_squared_logarithmic_error: 0.1820 - val_loss: 6791978746.8625 - val_mean_absolute_error: 62889.9648 - val_mean_squared_error: 6791979008.0000 - val_mean_squared_logarithmic_error: 0.1861
# Epoch 91/100
# 16342/16342 [==============================] - 2s 141us/sample - loss: 7201521843.2721 - mean_absolute_error: 63546.0078 - mean_squared_error: 7201523200.0000 - mean_squared_logarithmic_error: 0.1836 - val_loss: 6804519069.8855 - val_mean_absolute_error: 62157.3203 - val_mean_squared_error: 6804517376.0000 - val_mean_squared_logarithmic_error: 0.1798
# Epoch 92/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7190355519.4752 - mean_absolute_error: 63384.1953 - mean_squared_error: 7190353920.0000 - mean_squared_logarithmic_error: 0.1831 - val_loss: 6791730167.2286 - val_mean_absolute_error: 61402.3359 - val_mean_squared_error: 6791730176.0000 - val_mean_squared_logarithmic_error: 0.1769
# Epoch 93/100
# 16342/16342 [==============================] - 2s 141us/sample - loss: 7159707520.7989 - mean_absolute_error: 63219.6445 - mean_squared_error: 7159708672.0000 - mean_squared_logarithmic_error: 0.1819 - val_loss: 6786825849.7974 - val_mean_absolute_error: 62620.7500 - val_mean_squared_error: 6786825728.0000 - val_mean_squared_logarithmic_error: 0.1839
# Epoch 94/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7207427689.8338 - mean_absolute_error: 63421.6719 - mean_squared_error: 7207426560.0000 - mean_squared_logarithmic_error: 0.1832 - val_loss: 6783851688.2859 - val_mean_absolute_error: 61465.3867 - val_mean_squared_error: 6783853056.0000 - val_mean_squared_logarithmic_error: 0.1795
# Epoch 95/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7247727991.5251 - mean_absolute_error: 63604.7578 - mean_squared_error: 7247730176.0000 - mean_squared_logarithmic_error: 0.1838 - val_loss: 6740543827.3284 - val_mean_absolute_error: 61633.1797 - val_mean_squared_error: 6740542976.0000 - val_mean_squared_logarithmic_error: 0.1798
# Epoch 96/100
# 16342/16342 [==============================] - 2s 142us/sample - loss: 7200043856.3623 - mean_absolute_error: 63418.6055 - mean_squared_error: 7200047616.0000 - mean_squared_logarithmic_error: 0.1826 - val_loss: 6743671206.5316 - val_mean_absolute_error: 61327.8828 - val_mean_squared_error: 6743673344.0000 - val_mean_squared_logarithmic_error: 0.1774
# Epoch 97/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7179717526.6048 - mean_absolute_error: 63161.3555 - mean_squared_error: 7179718144.0000 - mean_squared_logarithmic_error: 0.1824 - val_loss: 6760163125.0044 - val_mean_absolute_error: 61417.2773 - val_mean_squared_error: 6760160768.0000 - val_mean_squared_logarithmic_error: 0.1790
# Epoch 98/100
# 16342/16342 [==============================] - 2s 138us/sample - loss: 7196678788.4646 - mean_absolute_error: 63437.3672 - mean_squared_error: 7196680704.0000 - mean_squared_logarithmic_error: 0.1834 - val_loss: 6915874159.1464 - val_mean_absolute_error: 63789.7422 - val_mean_squared_error: 6915874816.0000 - val_mean_squared_logarithmic_error: 0.1867
# Epoch 99/100
# 16342/16342 [==============================] - 2s 139us/sample - loss: 7215542368.5600 - mean_absolute_error: 63470.5430 - mean_squared_error: 7215540736.0000 - mean_squared_logarithmic_error: 0.1829 - val_loss: 6866247408.8380 - val_mean_absolute_error: 60658.2148 - val_mean_squared_error: 6866245632.0000 - val_mean_squared_logarithmic_error: 0.1739
# Epoch 100/100
# 16342/16342 [==============================] - 2s 140us/sample - loss: 7232524882.1481 - mean_absolute_error: 63444.4766 - mean_squared_error: 7232523264.0000 - mean_squared_logarithmic_error: 0.1832 - val_loss: 6779490497.4723 - val_mean_absolute_error: 62381.2461 - val_mean_squared_error: 6779489792.0000 - val_mean_squared_logarithmic_error: 0.1826

# %%
pyplot.title('Loss - Mean Squared Error')
pyplot.plot(history2.history['loss'], label='train')
pyplot.plot(history2.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
def plot_results(X, Y, Y_predict, plot_name):
    pyplot.figure()
    pyplot.scatter(Y, Y_predict)
    pyplot.grid()
    pyplot.xlabel("Real Values")
    pyplot.ylabel("Predictions")
    pyplot.figure()
    pyplot.scatter(X['median_income'], Y, label="values")
    pyplot.plot(X['median_income'], Y_predict, color="red", label="model")
    pyplot.grid()
    pyplot.xlabel("median_income")
    pyplot.ylabel("median_house_value")
    pyplot.legend()
test_predictions = model2.predict(x_v['median_income']).flatten()
plot_results(x_v, y_v, test_predictions, "results_nn.png")

# %% [markdown]
# Compare the results:

# %%
pyplot.title('Loss/Mean Squared Error')
pyplot.plot(history.history['loss'], 'r', label='train_1',)
pyplot.plot(history.history['val_loss'], 'b', label='validation_1')
pyplot.plot(history2.history['loss'], 'm', label='train_2')
pyplot.plot(history2.history['val_loss'], 'k', label='validation_2')
pyplot.legend()
pyplot.show()

# %%
pyplot.title('Loss/Mean Squared Error')
pyplot.plot(history.history['loss'][80:100], 'r', label='train_1',)
pyplot.plot(history.history['val_loss'][80:100], 'b', label='validation_1')
pyplot.plot(history2.history['loss'][80:100], 'm', label='train_2')
pyplot.plot(history2.history['val_loss'][80:100], 'k', label='validation_2')
pyplot.legend()
pyplot.show()

# %% [markdown]
# Looks like using multi variable, we have a better model.

# %% [markdown]
# Prediction:

# %%
test_predictions = model2.predict(x_v['median_income']).flatten()

predicted_loss = np.abs(y_v.values-test_predictions)/y_v.describe().transpose()['mean']

print("\nReal Median House Value:\n", y_v.values[0:4])
print("\nPredicted Median House Value:\n", test_predictions[0:4])
print("\nLoss:\n", predicted_loss[0:4])
print("\nMean Loss:", np.mean(predicted_loss))
# Out:
# Real Median House Value:
#  [182600. 201100.  74200. 245000.]
#
# Predicted Median House Value:
#  [170157.78 219253.48 147913.33 247170.86]
#
# Loss:
#  [0.06011349 0.08770696 0.35613946 0.01048832]
#
# Mean Loss: 0.3013895736618454

# %% [markdown]
# Plot the difference

# %%
test_predictions = model2.predict(x_v['median_income']).flatten()
pyplot.plot(range(len(predicted_loss)), predicted_loss)
